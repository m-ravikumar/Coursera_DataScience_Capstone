# %% [markdown]
# ## A Recommedation System for Tourism agency in DownTown Toronto

# %%
#import the packages
import pandas as pd
import numpy as np
import json
import requests
import geocoder
import folium
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup

# %%
#Lets import the toronto geo coordiantes and postal codes file
df_toronto = pd.read_csv("df_tornto_coords.csv").drop(df_toronto.columns[0],axis=1)
df_toronto.head()
# Out:
#   PostalCode           Borough                                  Neighbourhood   Latitude  Longitude
# 0        M5E  Downtown Toronto                                    Berczy Park  43.644771 -79.373306
# 1        M4W  Downtown Toronto                                       Rosedale  43.679563 -79.377529
# 2        M8Z         Etobicoke  Mimico NW, The Queensway West, South of Bloor  43.628841 -79.520999
# 3        M9M        North York                               Emery, Humberlea  43.724766 -79.532242
# 4        M1R       Scarborough                              Maryvale, Wexford  43.750071 -79.295849

# %% [markdown]
# ### Let's Visualize Toronto in World Map

# %%
toronto_latitude = 43.6932
toronto_longitude = -79.3832

map_toronto = folium.Map(location = [toronto_latitude, toronto_longitude], zoom_start = 10)

# add markers to each coordiates of the boroughs
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### This above map showing all the neghborhoods of each borough in Toronto City. But we would like to explore more on "Downtown Toronto" Borough  and it's Neighborhoods

# %%
# selecting only neighborhoods regarding to "downtown_toronto" borough.
downtown_data = df_toronto[df_toronto['Borough'] == 'Downtown Toronto']
downtown_data = downtown_data.reset_index(drop=True)
downtown_data.head()
# Out:
#   PostalCode           Borough                                      Neighbourhood   Latitude  Longitude
# 0        M5E  Downtown Toronto                                        Berczy Park  43.644771 -79.373306
# 1        M4W  Downtown Toronto                                           Rosedale  43.679563 -79.377529
# 2        M5V  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Sou...  43.628947 -79.394420
# 3        M5L  Downtown Toronto                                     Commerce Court  43.648198 -79.379817
# 4        M5B  Downtown Toronto                                            Ryerson  43.657162 -79.378937

# %% [markdown]
# ## Visualize the Downtown Toronto and its Neighborhoods on the World Map

# %%
# get the coordinates of the Downtown Toronto
latitude_downtown = 43.6543
longitude_downtown = -79.3860

map_Downtown = folium.Map(location=[latitude_downtown, longitude_downtown], zoom_start=11)

# add markers to map
for lat, lng, label in zip(downtown_data['Latitude'], downtown_data['Longitude'], downtown_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 10,
        popup = label,
        color ='blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7).add_to(map_Downtown)  
    
map_Downtown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Foursqure API to get nearest venues and other places around Downtown

# %%
# define the foursquare developer credentials
CLIENT_ID = '0MJA3NYYG3U2ZY1LTZN2OYEHS3Y3WVSON2GBSO3IL4EDYVIR' # your Foursquare ID
CLIENT_SECRET = 'WGWSAF2TKVUQPE3PD0N3EOITFVBY5EYP1VCZI3BMUG0ROUS5' # your Foursquare Secret
VERSION = '20181213' # Foursquare API version

# %%
def foursquare_crawler(postal_code_list, neighborhood_list, lat_list, lng_list, LIMIT = 500, radius = 1000):
    result_ds = []
    counter = 0
    for postal_code, neighborhood, lat, lng in zip(postal_code_list, neighborhood_list, lat_list, lng_list):
         
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, 
            lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        tmp_dict = {}
        tmp_dict['Postal Code'] = postal_code; tmp_dict['Neighborhood(s)'] = neighborhood; 
        tmp_dict['Latitude'] = lat; tmp_dict['Longitude'] = lng;
        tmp_dict['Crawling_result'] = results;
        result_ds.append(tmp_dict)
        counter += 1
        print('Details received for {} SUCCESSFULLY.'.format(neighborhood))
    return result_ds;

# %%
#Call the foursquare api to get all the near venue details for the Downtown
downtown_foursquare_dataset = foursquare_crawler(list(downtown_data['PostalCode']),
                                                   list(downtown_data['Neighbourhood']),
                                                   list(downtown_data['Latitude']),
                                                   list(downtown_data['Longitude']),)
# Out:
# Details received for Berczy Park SUCCESSFULLY.
# Details received for Rosedale SUCCESSFULLY.
# Details received for CN Tower, King and Spadina, Railway Lands, South Niagara SUCCESSFULLY.
# Details received for Commerce Court SUCCESSFULLY.
# Details received for Ryerson SUCCESSFULLY.
# Details received for Toronto Islands, Union Station SUCCESSFULLY.
# Details received for Design Exchange, Toronto Dominion Centre SUCCESSFULLY.
# Details received for University of Toronto SUCCESSFULLY.
# Details received for Adelaide, King SUCCESSFULLY.
# Details received for Church and Wellesley SUCCESSFULLY.
# Details received for St. James Town SUCCESSFULLY.
# Details received for First Canadian Place, Underground city SUCCESSFULLY.
# Details received for Chinatown, Grange Park, Kensington Market SUCCESSFULLY.
# Details received for Cabbagetown, St. James Town SUCCESSFULLY.
# Details received for Harbourfront, Regent Park SUCCESSFULLY.

# %%
downtown_foursquare_dataset
# Out:
# [{'Postal Code': 'M5E',
#   'Neighborhood(s)': 'Berczy Park',
#   'Latitude': 43.6447708,
#   'Longitude': -79.3733064,
#   'Crawling_result': [{'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b56a44ff964a5206e1728e3',
#      'name': 'The Keg Steakhouse + Bar',
#      'location': {'address': '26 The Esplanade',
#       'lat': 43.64667637593993,
#       'lng': -79.37482154865866,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64667637593993,
#         'lng': -79.37482154865866}],
#       'distance': 244,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['26 The Esplanade', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1cc941735',
#        'name': 'Steakhouse',
#        'pluralName': 'Steakhouses',
#        'shortName': 'Steakhouse',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b56a44ff964a5206e1728e3-0'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4aeb719af964a52020c221e3',
#      'name': 'LCBO',
#      'location': {'address': '2 Cooper St',
#       'crossStreet': 'at Queens Quay E',
#       'lat': 43.64294379917171,
#       'lng': -79.37243989044406,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64294379917171,
#         'lng': -79.37243989044406}],
#       'distance': 215,
#       'postalCode': 'M5E 1A4',
#       'cc': 'CA',
#       'neighborhood': 'Downtown Toronto',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['2 Cooper St (at Queens Quay E)',
#        'Toronto ON M5E 1A4',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d186941735',
#        'name': 'Liquor Store',
#        'pluralName': 'Liquor Stores',
#        'shortName': 'Liquor Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4aeb719af964a52020c221e3-1'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05ef964a520d8f620e3',
#      'name': 'Hockey Hall Of Fame (Hockey Hall of Fame)',
#      'location': {'address': '30 Yonge St.',
#       'crossStreet': 'at Brookfield Pl.',
#       'lat': 43.646974451431056,
#       'lng': -79.37732323942681,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.646974451431056,
#         'lng': -79.37732323942681}],
#       'distance': 406,
#       'postalCode': 'M5E 1X8',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['30 Yonge St. (at Brookfield Pl.)',
#        'Toronto ON M5E 1X8',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d181941735',
#        'name': 'Museum',
#        'pluralName': 'Museums',
#        'shortName': 'Museum',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c05ef964a520d8f620e3-2'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c062f964a520fbf720e3',
#      'name': 'St. Lawrence Market (South Building)',
#      'location': {'address': '93 Front St E',
#       'crossStreet': 'at Lower Jarvis St',
#       'lat': 43.64877797631841,
#       'lng': -79.37163741282026,
#       'distance': 465,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'neighborhood': 'St. Lawrence',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['93 Front St E (at Lower Jarvis St)',
#        'Toronto ON M5E 1C3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1fa941735',
#        'name': 'Farmers Market',
#        'pluralName': 'Farmers Markets',
#        'shortName': "Farmer's Market",
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c062f964a520fbf720e3-3'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '50b7c53616485cd9efad60d5',
#      'name': 'Sukhothai',
#      'location': {'address': '52 Wellington St. E.',
#       'crossStreet': 'at Church St',
#       'lat': 43.64848710249909,
#       'lng': -79.37454735245633,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64848710249909,
#         'lng': -79.37454735245633}],
#       'distance': 425,
#       'postalCode': 'M5E 1C9',
#       'cc': 'CA',
#       'neighborhood': 'St. Lawrence',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['52 Wellington St. E. (at Church St)',
#        'Toronto ON M5E 1C9',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d149941735',
#        'name': 'Thai Restaurant',
#        'pluralName': 'Thai Restaurants',
#        'shortName': 'Thai',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-50b7c53616485cd9efad60d5-4'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c062f964a520b8f720e3',
#      'name': 'Sony Centre for the Performing Arts',
#      'location': {'address': '1 Front St E',
#       'crossStreet': 'at Yonge St',
#       'lat': 43.646292124205594,
#       'lng': -79.37602179505662,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.646292124205594,
#         'lng': -79.37602179505662}],
#       'distance': 276,
#       'postalCode': 'M5E 1B2',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['1 Front St E (at Yonge St)',
#        'Toronto ON M5E 1B2',
#        'Canada']},
#      'categories': [{'id': '5032792091d4c4b30a586d5c',
#        'name': 'Concert Hall',
#        'pluralName': 'Concert Halls',
#        'shortName': 'Concert Hall',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c062f964a520b8f720e3-5'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4bbe53a1848da593e522ea6d',
#      'name': 'St. Lawrence Market (North Building)',
#      'location': {'address': '92 Front St. E',
#       'crossStreet': 'at Jarvis St.',
#       'lat': 43.64879290161719,
#       'lng': -79.37194535820687,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64879290161719,
#         'lng': -79.37194535820687}],
#       'distance': 460,
#       'postalCode': 'M5E 1C4',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['92 Front St. E (at Jarvis St.)',
#        'Toronto ON M5E 1C4',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1fa941735',
#        'name': 'Farmers Market',
#        'pluralName': 'Farmers Markets',
#        'shortName': "Farmer's Market",
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4bbe53a1848da593e522ea6d-6'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '53361f24498e6a4d4d8f66f1',
#      'name': 'D.W. Alexander',
#      'location': {'address': '19 Church St',
#       'crossStreet': 'Front St. E.',
#       'lat': 43.64833304339161,
#       'lng': -79.3738261420116,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64833304339161,
#         'lng': -79.3738261420116}],
#       'distance': 398,
#       'postalCode': 'M5E 1M2',
#       'cc': 'CA',
#       'neighborhood': 'St. Lawrence',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['19 Church St (Front St. E.)',
#        'Toronto ON M5E 1M2',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d11e941735',
#        'name': 'Cocktail Bar',
#        'pluralName': 'Cocktail Bars',
#        'shortName': 'Cocktail',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-53361f24498e6a4d4d8f66f1-7'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b155081f964a520b4b023e3',
#      'name': 'Scotiabank Arena',
#      'location': {'address': '40 Bay St',
#       'lat': 43.64344617535107,
#       'lng': -79.37903988889991,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64344617535107,
#         'lng': -79.37903988889991}],
#       'distance': 484,
#       'postalCode': 'M5J 2X2',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['40 Bay St', 'Toronto ON M5J 2X2', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d18b941735',
#        'name': 'Basketball Stadium',
#        'pluralName': 'Basketball Stadiums',
#        'shortName': 'Basketball',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_basketball_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '33431410'}},
#     'referralId': 'e-0-4b155081f964a520b4b023e3-8'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4fcb97f7e4b00a0e8520b055',
#      'name': 'Hogtown Smoke',
#      'location': {'address': '1959 Queen St E',
#       'lat': 43.64928693557788,
#       'lng': -79.37468932637938,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64928693557788,
#         'lng': -79.37468932637938}],
#       'distance': 514,
#       'postalCode': 'M4L 1H7',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['1959 Queen St E', 'Toronto ON M4L 1H7', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1cb941735',
#        'name': 'Food Truck',
#        'pluralName': 'Food Trucks',
#        'shortName': 'Food Truck',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '41352822'}},
#     'referralId': 'e-0-4fcb97f7e4b00a0e8520b055-9'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05cf964a520e3f520e3',
#      'name': "C'est What",
#      'location': {'address': '67 Front St E',
#       'crossStreet': 'at Church St',
#       'lat': 43.64846662325689,
#       'lng': -79.37337717995771,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64846662325689,
#         'lng': -79.37337717995771}],
#       'distance': 411,
#       'postalCode': 'M5E 1B5',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['67 Front St E (at Church St)',
#        'Toronto ON M5E 1B5',
#        'Canada']},
#      'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#        'name': 'Beer Bar',
#        'pluralName': 'Beer Bars',
#        'shortName': 'Beer Bar',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '50003822'}},
#     'referralId': 'e-0-4ad4c05cf964a520e3f520e3-10'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '56201ed4498e7f700c462170',
#      'name': 'Miku',
#      'location': {'address': '105-10 Bay St',
#       'crossStreet': 'at Queens Quay W',
#       'lat': 43.64125494342613,
#       'lng': -79.37737058692055,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64125494342613,
#         'lng': -79.37737058692055}],
#       'distance': 510,
#       'postalCode': 'M5J 2R8',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['105-10 Bay St (at Queens Quay W)',
#        'Toronto ON M5J 2R8',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d111941735',
#        'name': 'Japanese Restaurant',
#        'pluralName': 'Japanese Restaurants',
#        'shortName': 'Japanese',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-56201ed4498e7f700c462170-11'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b86b209f964a520cf9631e3',
#      'name': "Buster's Sea Cove",
#      'location': {'address': '93 Front St. E.',
#       'crossStreet': 'Upper Level 33',
#       'lat': 43.6484950904393,
#       'lng': -79.37146231793892,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.6484950904393,
#         'lng': -79.37146231793892}],
#       'distance': 440,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['93 Front St. E. (Upper Level 33)',
#        'Toronto ON M5E 1C3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1ce941735',
#        'name': 'Seafood Restaurant',
#        'pluralName': 'Seafood Restaurants',
#        'shortName': 'Seafood',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b86b209f964a520cf9631e3-12'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '534effeb498e6464d5c4885c',
#      'name': 'Market Street Catch',
#      'location': {'address': '14 Market St.',
#       'crossStreet': 'at Front St. E.',
#       'lat': 43.64850142396483,
#       'lng': -79.3718080237409,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64850142396483,
#         'lng': -79.3718080237409}],
#       'distance': 432,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['14 Market St. (at Front St. E.)',
#        'Toronto ON M5E 1C3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1ce941735',
#        'name': 'Seafood Restaurant',
#        'pluralName': 'Seafood Restaurants',
#        'shortName': 'Seafood',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-534effeb498e6464d5c4885c-13'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05df964a5205df620e3',
#      'name': 'Pravda Vodka Bar',
#      'location': {'address': '44 Wellington St. E',
#       'lat': 43.64851553067474,
#       'lng': -79.37473231149953,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64851553067474,
#         'lng': -79.37473231149953}],
#       'distance': 432,
#       'postalCode': 'M5E 1C9',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['44 Wellington St. E',
#        'Toronto ON M5E 1C9',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d11e941735',
#        'name': 'Cocktail Bar',
#        'pluralName': 'Cocktail Bars',
#        'shortName': 'Cocktail',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c05df964a5205df620e3-14'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4bb79860cf2fc9b616779e02',
#      'name': 'Berczy Park',
#      'location': {'address': '35 Wellington St. East',
#       'lat': 43.64804835388851,
#       'lng': -79.3751722909452,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64804835388851,
#         'lng': -79.3751722909452}],
#       'distance': 394,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['35 Wellington St. East', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d163941735',
#        'name': 'Park',
#        'pluralName': 'Parks',
#        'shortName': 'Park',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4bb79860cf2fc9b616779e02-15'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b0f3cd2f964a520b66023e3',
#      'name': "Biff's Bistro",
#      'location': {'address': '4 Front Street East',
#       'crossStreet': 'at Yonge St.',
#       'lat': 43.647084825125084,
#       'lng': -79.37634231908494,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.647084825125084,
#         'lng': -79.37634231908494}],
#       'distance': 355,
#       'postalCode': 'M5E 1G4',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['4 Front Street East (at Yonge St.)',
#        'Toronto ON M5E 1G4',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10c941735',
#        'name': 'French Restaurant',
#        'pluralName': 'French Restaurants',
#        'shortName': 'French',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '41473018'}},
#     'referralId': 'e-0-4b0f3cd2f964a520b66023e3-16'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4be46c832468c92887c1fe42',
#      'name': 'Real Sports Apparel',
#      'location': {'address': '15 York St. Unit B',
#       'crossStreet': 'Maple Leaf Square',
#       'lat': 43.64285984835777,
#       'lng': -79.38018363195047,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64285984835777,
#         'lng': -79.38018363195047}],
#       'distance': 593,
#       'postalCode': 'M5J',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['15 York St. Unit B (Maple Leaf Square)',
#        'Toronto ON M5J',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1f2941735',
#        'name': 'Sporting Goods Shop',
#        'pluralName': 'Sporting Goods Shops',
#        'shortName': 'Sporting Goods',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '33431415'}},
#     'referralId': 'e-0-4be46c832468c92887c1fe42-17'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4e67c316483bef6eb8171e49',
#      'name': 'DAVIDsTEA',
#      'location': {'address': '100 King St W',
#       'lat': 43.646657736285796,
#       'lng': -79.37764102856944,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.646657736285796,
#         'lng': -79.37764102856944}],
#       'distance': 407,
#       'postalCode': 'M5X 1B8',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['100 King St W', 'Toronto ON M5X 1B8', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1dc931735',
#        'name': 'Tea Room',
#        'pluralName': 'Tea Rooms',
#        'shortName': 'Tea Room',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4e67c316483bef6eb8171e49-18'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '563d2f2dcd10bcf27ae37c3b',
#      'name': 'Pilot Coffee Roasters',
#      'location': {'lat': 43.64501814464698,
#       'lng': -79.3804150931199,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64501814464698,
#         'lng': -79.3804150931199}],
#       'distance': 573,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-563d2f2dcd10bcf27ae37c3b-19'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '5980a832898bdc3d188e85b9',
#      'name': 'FARMR Eatery & Catering',
#      'location': {'address': '140A The Esplanade',
#       'crossStreet': 'Jarvis',
#       'lat': 43.648419863375096,
#       'lng': -79.37027379521088,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.648419863375096,
#         'lng': -79.37027379521088}],
#       'distance': 474,
#       'postalCode': 'M5A 4P5',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['140A The Esplanade (Jarvis)',
#        'Toronto ON M5A 4P5',
#        'Canada']},
#      'categories': [{'id': '52e81612bcbc57f1066b79f1',
#        'name': 'Bistro',
#        'pluralName': 'Bistros',
#        'shortName': 'Bistro',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-5980a832898bdc3d188e85b9-20'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c6eb1c9c524370414ae2beb',
#      'name': 'Stonemill Bread',
#      'location': {'address': 'St. Lawrence Market',
#       'crossStreet': 'Lower level',
#       'lat': 43.648668221542096,
#       'lng': -79.37160962302049,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.648668221542096,
#         'lng': -79.37160962302049}],
#       'distance': 454,
#       'cc': 'CA',
#       'neighborhood': 'St. Lawrence',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['St. Lawrence Market (Lower level)',
#        'Toronto ON',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16a941735',
#        'name': 'Bakery',
#        'pluralName': 'Bakeries',
#        'shortName': 'Bakery',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c6eb1c9c524370414ae2beb-21'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05df964a52060f620e3',
#      'name': 'The Reservoir Lounge',
#      'location': {'address': '52 Wellington St. E',
#       'crossStreet': 'btwn Church St. and Yonge St.',
#       'lat': 43.64851659851552,
#       'lng': -79.37455623391588,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64851659851552,
#         'lng': -79.37455623391588}],
#       'distance': 428,
#       'postalCode': 'M5E 1C9',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['52 Wellington St. E (btwn Church St. and Yonge St.)',
#        'Toronto ON M5E 1C9',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1e7931735',
#        'name': 'Jazz Club',
#        'pluralName': 'Jazz Clubs',
#        'shortName': 'Jazz Club',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c05df964a52060f620e3-22'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '52138db911d22803b334c641',
#      'name': 'Mos Mos Coffee',
#      'location': {'address': 'Commerce Court East',
#       'lat': 43.64815919753501,
#       'lng': -79.37874450467258,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64815919753501,
#         'lng': -79.37874450467258}],
#       'distance': 578,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['Commerce Court East', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-52138db911d22803b334c641-23'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b60d5b9f964a52071fc29e3',
#      'name': 'Air Canada Club',
#      'location': {'address': 'Air Canada Centre',
#       'lat': 43.643224100030416,
#       'lng': -79.37915938219528,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.643224100030416,
#         'lng': -79.37915938219528}],
#       'distance': 501,
#       'postalCode': 'M5J 2L2',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['Air Canada Centre',
#        'Toronto ON M5J 2L2',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d121941735',
#        'name': 'Lounge',
#        'pluralName': 'Lounges',
#        'shortName': 'Lounge',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b60d5b9f964a52071fc29e3-24'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b8010c5f964a520054f30e3',
#      'name': 'Seafront Fish Market',
#      'location': {'address': '93 Front St E',
#       'lat': 43.6484785341064,
#       'lng': -79.37148942972523,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.6484785341064,
#         'lng': -79.37148942972523}],
#       'distance': 437,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['93 Front St E', 'Toronto ON M5E 1C3', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10e951735',
#        'name': 'Fish Market',
#        'pluralName': 'Fish Markets',
#        'shortName': 'Fish Market',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_fishmarket_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b8010c5f964a520054f30e3-25'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '55314880498eca93a62e17ec',
#      'name': 'Movenpick Cafe',
#      'location': {'address': 'Wellington',
#       'crossStreet': 'Yonge',
#       'lat': 43.647686808930885,
#       'lng': -79.3772953884033,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.647686808930885,
#         'lng': -79.3772953884033}],
#       'distance': 456,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['Wellington (Yonge)', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-55314880498eca93a62e17ec-26'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b5ca7d8f964a5207c3c29e3',
#      'name': 'Beerbistro',
#      'location': {'address': '18 King St. E',
#       'crossStreet': 'at Yonge St.',
#       'lat': 43.64941904378835,
#       'lng': -79.37723726034164,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64941904378835,
#         'lng': -79.37723726034164}],
#       'distance': 606,
#       'postalCode': 'M5C 1C4',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['18 King St. E (at Yonge St.)',
#        'Toronto ON M5C 1C4',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d155941735',
#        'name': 'Gastropub',
#        'pluralName': 'Gastropubs',
#        'shortName': 'Gastropub',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '113282121'}},
#     'referralId': 'e-0-4b5ca7d8f964a5207c3c29e3-27'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b647148f964a52080b32ae3',
#      'name': 'Carousel Bakery',
#      'location': {'address': 'St Lawrence Market',
#       'crossStreet': 'Upper Level 42',
#       'lat': 43.6487072781773,
#       'lng': -79.37158005127563,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.6487072781773,
#         'lng': -79.37158005127563}],
#       'distance': 459,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['St Lawrence Market (Upper Level 42)',
#        'Toronto ON M5E 1C3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16a941735',
#        'name': 'Bakery',
#        'pluralName': 'Bakeries',
#        'shortName': 'Bakery',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b647148f964a52080b32ae3-28'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4adf7d0bf964a520127b21e3',
#      'name': 'The Omni King Edward Hotel',
#      'location': {'address': '37 King Street East',
#       'crossStreet': 'bwtn Victoria St. and Toronto St.',
#       'lat': 43.64919051601911,
#       'lng': -79.37600612640387,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64919051601911,
#         'lng': -79.37600612640387}],
#       'distance': 537,
#       'postalCode': 'M5C 1E9',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['37 King Street East (bwtn Victoria St. and Toronto St.)',
#        'Toronto ON M5C 1E9',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1fa931735',
#        'name': 'Hotel',
#        'pluralName': 'Hotels',
#        'shortName': 'Hotel',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '51136538'}},
#     'referralId': 'e-0-4adf7d0bf964a520127b21e3-29'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '536fd522498e09c6690800e2',
#      'name': "Balzac's Coffee",
#      'location': {'address': '10 Market Street',
#       'crossStreet': 'btwn The Esplanade & Front St. E.',
#       'lat': 43.64845650131932,
#       'lng': -79.37178993724407,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64845650131932,
#         'lng': -79.37178993724407}],
#       'distance': 428,
#       'postalCode': 'M5E 1M6',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['10 Market Street (btwn The Esplanade & Front St. E.)',
#        'Toronto ON M5E 1M6',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16d941735',
#        'name': 'Café',
#        'pluralName': 'Cafés',
#        'shortName': 'Café',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-536fd522498e09c6690800e2-30'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4baa4b39f964a520ec5b3ae3',
#      'name': 'Marché Restaurant',
#      'location': {'address': '181 Bay St.',
#       'crossStreet': 'in Brookfield Place',
#       'lat': 43.64723237089591,
#       'lng': -79.37759119081164,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64723237089591,
#         'lng': -79.37759119081164}],
#       'distance': 440,
#       'postalCode': 'M5J 2T3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['181 Bay St. (in Brookfield Place)',
#        'Toronto ON M5J 2T3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1c4941735',
#        'name': 'Restaurant',
#        'pluralName': 'Restaurants',
#        'shortName': 'Restaurant',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '59869170'}},
#     'referralId': 'e-0-4baa4b39f964a520ec5b3ae3-31'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ae73054f964a5203ca921e3',
#      'name': 'Ki Modern Japanese + Bar',
#      'location': {'address': '181 Bay St',
#       'crossStreet': 'at Wellington St. W',
#       'lat': 43.64710349021134,
#       'lng': -79.37938978621831,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64710349021134,
#         'lng': -79.37938978621831}],
#       'distance': 554,
#       'postalCode': 'M5J 2T3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['181 Bay St (at Wellington St. W)',
#        'Toronto ON M5J 2T3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d111941735',
#        'name': 'Japanese Restaurant',
#        'pluralName': 'Japanese Restaurants',
#        'shortName': 'Japanese',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ae73054f964a5203ca921e3-32'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c8102a1d8086dcb21866852',
#      'name': "Scheffler's Deli",
#      'location': {'address': 'St Lawrence Market, 93 Front St. E',
#       'crossStreet': 'btwn Market & Lower Jarvis',
#       'lat': 43.648643353516086,
#       'lng': -79.37153681663685,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.648643353516086,
#         'lng': -79.37153681663685}],
#       'distance': 454,
#       'postalCode': 'M5E 1C3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['St Lawrence Market, 93 Front St. E (btwn Market & Lower Jarvis)',
#        'Toronto ON M5E 1C3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d11e951735',
#        'name': 'Cheese Shop',
#        'pluralName': 'Cheese Shops',
#        'shortName': 'Cheese Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_cheese_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4c8102a1d8086dcb21866852-33'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '501ae947e4b0d11883b910a7',
#      'name': 'Equinox Bay Street',
#      'location': {'address': '199 Bay St',
#       'crossStreet': 'at Commerce Court West, PATH Level',
#       'lat': 43.64809974034856,
#       'lng': -79.37998869411526,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64809974034856,
#         'lng': -79.37998869411526}],
#       'distance': 653,
#       'postalCode': 'M5L 1L5',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['199 Bay St (at Commerce Court West, PATH Level)',
#        'Toronto ON M5L 1L5',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d176941735',
#        'name': 'Gym',
#        'pluralName': 'Gyms',
#        'shortName': 'Gym',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-501ae947e4b0d11883b910a7-34'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4af71c9df964a520fc0522e3',
#      'name': 'Aveda Institute Toronto',
#      'location': {'address': '125 King St. E',
#       'crossStreet': 'at Church St.',
#       'lat': 43.65009640955562,
#       'lng': -79.37362952211767,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.65009640955562,
#         'lng': -79.37362952211767}],
#       'distance': 593,
#       'postalCode': 'M5C 1G6',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['125 King St. E (at Church St.)',
#        'Toronto ON M5C 1G6',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10c951735',
#        'name': 'Cosmetics Shop',
#        'pluralName': 'Cosmetics Shops',
#        'shortName': 'Cosmetics',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4af71c9df964a520fc0522e3-35'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '583f54320923922e8141d360',
#      'name': 'Crepe TO',
#      'location': {'address': '52 Church Street',
#       'lat': 43.650063279511016,
#       'lng': -79.37458664523871,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.650063279511016,
#         'lng': -79.37458664523871}],
#       'distance': 598,
#       'postalCode': 'M5C 3C8',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['52 Church Street',
#        'Toronto ON M5C 3C8',
#        'Canada']},
#      'categories': [{'id': '52e81612bcbc57f1066b79f2',
#        'name': 'Creperie',
#        'pluralName': 'Creperies',
#        'shortName': 'Creperie',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-583f54320923922e8141d360-36'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c05b0ce5753c92838e739f1',
#      'name': 'Real Sports Bar & Grill',
#      'location': {'address': '15 York St',
#       'crossStreet': 'at Bremner Blvd',
#       'lat': 43.64283099171422,
#       'lng': -79.38009454098032,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64283099171422,
#         'lng': -79.38009454098032}],
#       'distance': 587,
#       'postalCode': 'M5J 0A3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['15 York St (at Bremner Blvd)',
#        'Toronto ON M5J 0A3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d11d941735',
#        'name': 'Sports Bar',
#        'pluralName': 'Sports Bars',
#        'shortName': 'Sports Bar',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '33431419'}},
#     'referralId': 'e-0-4c05b0ce5753c92838e739f1-37'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05df964a52055f620e3',
#      'name': 'Bier Markt Esplanade',
#      'location': {'address': '58 The Esplanade',
#       'crossStreet': 'at Church St.',
#       'lat': 43.64723602476138,
#       'lng': -79.37389161769812,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64723602476138,
#         'lng': -79.37389161769812}],
#       'distance': 278,
#       'postalCode': 'M5E 1A6',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['58 The Esplanade (at Church St.)',
#        'Toronto ON M5E 1A6',
#        'Canada']},
#      'categories': [{'id': '52e81612bcbc57f1066b7a02',
#        'name': 'Belgian Restaurant',
#        'pluralName': 'Belgian Restaurants',
#        'shortName': 'Belgian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c05df964a52055f620e3-38'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad7b757f964a520ff0d21e3',
#      'name': 'Harbour Sixty Steakhouse',
#      'location': {'address': '60 Harbour St.',
#       'crossStreet': 'at Yonge St.',
#       'lat': 43.64222021431867,
#       'lng': -79.37794459004243,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64222021431867,
#         'lng': -79.37794459004243}],
#       'distance': 469,
#       'postalCode': 'M5J 1B7',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['60 Harbour St. (at Yonge St.)',
#        'Toronto ON M5J 1B7',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1cc941735',
#        'name': 'Steakhouse',
#        'pluralName': 'Steakhouses',
#        'shortName': 'Steakhouse',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad7b757f964a520ff0d21e3-39'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad4c05bf964a520a7f520e3',
#      'name': 'The Fairmont Royal York',
#      'location': {'address': '100 Front St W',
#       'crossStreet': 'btwn York St & Bay St',
#       'lat': 43.64544914616651,
#       'lng': -79.3815076529019,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64544914616651,
#         'lng': -79.3815076529019}],
#       'distance': 664,
#       'postalCode': 'M5J 1E3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['100 Front St W (btwn York St & Bay St)',
#        'Toronto ON M5J 1E3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1fa931735',
#        'name': 'Hotel',
#        'pluralName': 'Hotels',
#        'shortName': 'Hotel',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad4c05bf964a520a7f520e3-40'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4c2e1fc7e116e21eb5bc8f60',
#      'name': 'Sugar Beach',
#      'location': {'address': "Queen's Quay E",
#       'crossStreet': 'at Jarvis St',
#       'lat': 43.643379816203485,
#       'lng': -79.36744155499679,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.643379816203485,
#         'lng': -79.36744155499679}],
#       'distance': 497,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ["Queen's Quay E (at Jarvis St)",
#        'Toronto ON',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1e2941735',
#        'name': 'Beach',
#        'pluralName': 'Beaches',
#        'shortName': 'Beach',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
# ...
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []},
#      'venuePage': {'id': '57512678'}},
#     'referralId': 'e-0-4ae9c117f964a52019b621e3-85'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b646bedf964a520d5b12ae3',
#      'name': 'Pet Cuisine',
#      'location': {'address': '127 Front St E',
#       'crossStreet': 'at George Street',
#       'lat': 43.64997022077983,
#       'lng': -79.36992359146845,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64997022077983,
#         'lng': -79.36992359146845}],
#       'distance': 887,
#       'postalCode': 'M5A 1E3',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['127 Front St E (at George Street)',
#        'Toronto ON M5A 1E3',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d100951735',
#        'name': 'Pet Store',
#        'pluralName': 'Pet Stores',
#        'shortName': 'Pet Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b646bedf964a520d5b12ae3-86'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ee1490961aff90fe37e76da',
#      'name': 'Qi sushi',
#      'location': {'address': '358 Gerrard St.E.',
#       'lat': 43.66255180762697,
#       'lng': -79.36425843422568,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.66255180762697,
#         'lng': -79.36425843422568}],
#       'distance': 968,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['358 Gerrard St.E.', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1d2941735',
#        'name': 'Sushi Restaurant',
#        'pluralName': 'Sushi Restaurants',
#        'shortName': 'Sushi',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ee1490961aff90fe37e76da-87'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4af9a379f964a520c91222e3',
#      'name': 'Bombay Palace',
#      'location': {'address': '71 Jarvis St',
#       'crossStreet': 'King',
#       'lat': 43.65117354457489,
#       'lng': -79.37213984452025,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.65117354457489,
#         'lng': -79.37213984452025}],
#       'distance': 988,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['71 Jarvis St (King)', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10f941735',
#        'name': 'Indian Restaurant',
#        'pluralName': 'Indian Restaurants',
#        'shortName': 'Indian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4af9a379f964a520c91222e3-88'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b8acdfdf964a520378232e3',
#      'name': 'The Beer Store',
#      'location': {'address': '28 River Street',
#       'crossStreet': 'Queen St E',
#       'lat': 43.657773,
#       'lng': -79.3574632,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.657773,
#         'lng': -79.3574632}],
#       'distance': 467,
#       'postalCode': 'M5A 3N9',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['28 River Street (Queen St E)',
#        'Toronto ON M5A 3N9',
#        'Canada']},
#      'categories': [{'id': '5370f356bcbc57f1066c94c2',
#        'name': 'Beer Store',
#        'pluralName': 'Beer Stores',
#        'shortName': 'Beer Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b8acdfdf964a520378232e3-89'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4ad8d551f964a5201f1521e3',
#      'name': 'Vistek',
#      'location': {'address': '496 Queen St E',
#       'crossStreet': 'at Sumach',
#       'lat': 43.65704640025721,
#       'lng': -79.35966695607046,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.65704640025721,
#         'lng': -79.35966695607046}],
#       'distance': 319,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['496 Queen St E (at Sumach)',
#        'Toronto ON',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d122951735',
#        'name': 'Electronics Store',
#        'pluralName': 'Electronics Stores',
#        'shortName': 'Electronics',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4ad8d551f964a5201f1521e3-90'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '54d7ab36498e189aaed34185',
#      'name': 'b.good',
#      'location': {'address': '100 Front St.',
#       'lat': 43.64959138517889,
#       'lng': -79.37120310814649,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.64959138517889,
#         'lng': -79.37120310814649}],
#       'distance': 997,
#       'postalCode': 'M5A 1E1',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['100 Front St.', 'Toronto ON M5A 1E1', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d16c941735',
#        'name': 'Burger Joint',
#        'pluralName': 'Burger Joints',
#        'shortName': 'Burgers',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-54d7ab36498e189aaed34185-91'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b4b60e5f964a520619926e3',
#      'name': 'Sakura Ichiban Japanese Cuisine',
#      'location': {'address': '142 Adelaide St. E.',
#       'lat': 43.651624139281495,
#       'lng': -79.37246371370311,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.651624139281495,
#         'lng': -79.37246371370311}],
#       'distance': 996,
#       'postalCode': 'M5C 1K9',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['142 Adelaide St. E.',
#        'Toronto ON M5C 1K9',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d111941735',
#        'name': 'Japanese Restaurant',
#        'pluralName': 'Japanese Restaurants',
#        'shortName': 'Japanese',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b4b60e5f964a520619926e3-92'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4d126fd3d1848cfad5cfbb71',
#      'name': 'TD Canada Trust',
#      'location': {'address': '457 Front Street East',
#       'lat': 43.652779762702764,
#       'lng': -79.3563362625656,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.652779762702764,
#         'lng': -79.3563362625656}],
#       'distance': 383,
#       'postalCode': 'M5A 0J2',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['457 Front Street East',
#        'Toronto ON M5A 0J2',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10a951735',
#        'name': 'Bank',
#        'pluralName': 'Banks',
#        'shortName': 'Bank',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4d126fd3d1848cfad5cfbb71-93'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4bca1f87b6c49c74e3d28f91',
#      'name': 'Moss Park Arena',
#      'location': {'address': '140 Sherbourne Street',
#       'crossStreet': 'Queen Street East',
#       'lat': 43.65488712314853,
#       'lng': -79.36977129447679,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.65488712314853,
#         'lng': -79.36977129447679}],
#       'distance': 739,
#       'cc': 'CA',
#       'city': 'Toronto Division',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['140 Sherbourne Street (Queen Street East)',
#        'Toronto Division ON',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d168941735',
#        'name': 'Skating Rink',
#        'pluralName': 'Skating Rinks',
#        'shortName': 'Skating Rink',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skatingrink_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4bca1f87b6c49c74e3d28f91-94'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4adc95f3f964a520912d21e3',
#      'name': 'Sushi Bar',
#      'location': {'address': '703 Queen Street East',
#       'crossStreet': 'Broadview',
#       'lat': 43.65879825022111,
#       'lng': -79.35008516753265,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.65879825022111,
#         'lng': -79.35008516753265}],
#       'distance': 988,
#       'postalCode': 'M4M',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['703 Queen Street East (Broadview)',
#        'Toronto ON M4M',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1d2941735',
#        'name': 'Sushi Restaurant',
#        'pluralName': 'Sushi Restaurants',
#        'shortName': 'Sushi',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4adc95f3f964a520912d21e3-95'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b2cf78cf964a52077cb24e3',
#      'name': 'Savoury Grounds',
#      'location': {'address': '481 Queen St. East',
#       'crossStreet': 'Sumach St',
#       'lat': 43.656820970004496,
#       'lng': -79.3589698353747,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.656820970004496,
#         'lng': -79.3589698353747}],
#       'distance': 315,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['481 Queen St. East (Sumach St)',
#        'Toronto ON',
#        'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d1e0931735',
#        'name': 'Coffee Shop',
#        'pluralName': 'Coffee Shops',
#        'shortName': 'Coffee Shop',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b2cf78cf964a52077cb24e3-96'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '52af6dc5498e33995b0bbf03',
#      'name': 'Sultan Of Samosas',
#      'location': {'address': '1 Oak Street',
#       'lat': 43.66022749787444,
#       'lng': -79.36622571571063,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.66022749787444,
#         'lng': -79.36622571571063}],
#       'distance': 802,
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['1 Oak Street', 'Toronto ON', 'Canada']},
#      'categories': [{'id': '4bf58dd8d48988d10f941735',
#        'name': 'Indian Restaurant',
#        'pluralName': 'Indian Restaurants',
#        'shortName': 'Indian',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-52af6dc5498e33995b0bbf03-97'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b845382f964a520dc2e31e3',
#      'name': 'Mercedes-Benz Downtown',
#      'location': {'address': '761 Dundas Street East',
#       'lat': 43.66143119502613,
#       'lng': -79.35658517368444,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.66143119502613,
#         'lng': -79.35658517368444}],
#       'distance': 862,
#       'postalCode': 'M5A 4N5',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['761 Dundas Street East',
#        'Toronto ON M5A 4N5',
#        'Canada']},
#      'categories': [{'id': '4eb1c1623b7b52c0e1adc2ec',
#        'name': 'Auto Dealership',
#        'pluralName': 'Auto Dealerships',
#        'shortName': 'Auto Dealer',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b845382f964a520dc2e31e3-98'},
#    {'reasons': {'count': 0,
#      'items': [{'summary': 'This spot is popular',
#        'type': 'general',
#        'reasonName': 'globalInteractionReason'}]},
#     'venue': {'id': '4b1e9904f964a520501c24e3',
#      'name': 'Dollarama',
#      'location': {'address': '149 Sherbourne St',
#       'crossStreet': 'at Shuter',
#       'lat': 43.655693765303965,
#       'lng': -79.36966323862772,
#       'labeledLatLngs': [{'label': 'display',
#         'lat': 43.655693765303965,
#         'lng': -79.36966323862772}],
#       'distance': 744,
#       'postalCode': 'M5A 2R5',
#       'cc': 'CA',
#       'city': 'Toronto',
#       'state': 'ON',
#       'country': 'Canada',
#       'formattedAddress': ['149 Sherbourne St (at Shuter)',
#        'Toronto ON M5A 2R5',
#        'Canada']},
#      'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#        'name': 'Discount Store',
#        'pluralName': 'Discount Stores',
#        'shortName': 'Discount Store',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#         'suffix': '.png'},
#        'primary': True}],
#      'photos': {'count': 0, 'groups': []}},
#     'referralId': 'e-0-4b1e9904f964a520501c24e3-99'}]}]

# %% [markdown]
# ## It seems it is unstructured format of venue details and we need to clean it. Let's explore

# %%
# This function is created to connect to the saved list which is the received database. 
#It will extract each venue for every neighborhood inside the database

def get_venue_dataset(downtown_foursquare_dataset):
    result_df = pd.DataFrame(columns = ['Postal Code', 'Neighborhood', 
                                           'Neighborhood Latitude', 'Neighborhood Longitude',
                                          'Venue', 'Venue Summary', 'Venue Category', 'Distance'])
        
    for neigh_dict in downtown_foursquare_dataset:
        postal_code = neigh_dict['Postal Code']; neigh = neigh_dict['Neighborhood(s)']
        lat = neigh_dict['Latitude']; lng = neigh_dict['Longitude']
        print('Number of Venuse in Coordination in {} Negihborhood(s) is {}:'.format(neigh,len(neigh_dict['Crawling_result'])))
        
        for venue_dict in neigh_dict['Crawling_result']:
            summary = venue_dict['reasons']['items'][0]['summary']
            name = venue_dict['venue']['name']
            dist = venue_dict['venue']['location']['distance']
            cat =  venue_dict['venue']['categories'][0]['name']
            
            result_df = result_df.append({'Postal Code': postal_code, 'Neighborhood': neigh, 
                              'Neighborhood Latitude': lat, 'Neighborhood Longitude':lng,
                              'Venue': name, 'Venue Summary': summary, 
                              'Venue Category': cat, 'Distance': dist}, ignore_index = True)
    
    return(result_df)

# %%
downtown_venues = get_venue_dataset(downtown_foursquare_dataset)
# Out:
# Number of Venuse in Coordination in Berczy Park Negihborhood(s) is 100:
# Number of Venuse in Coordination in Rosedale Negihborhood(s) is 26:
# Number of Venuse in Coordination in CN Tower, King and Spadina, Railway Lands, South Niagara Negihborhood(s) is 14:
# Number of Venuse in Coordination in Commerce Court Negihborhood(s) is 100:
# Number of Venuse in Coordination in Ryerson Negihborhood(s) is 100:
# Number of Venuse in Coordination in Toronto Islands, Union Station Negihborhood(s) is 100:
# Number of Venuse in Coordination in Design Exchange, Toronto Dominion Centre Negihborhood(s) is 100:
# Number of Venuse in Coordination in University of Toronto Negihborhood(s) is 100:
# Number of Venuse in Coordination in Adelaide, King Negihborhood(s) is 100:
# Number of Venuse in Coordination in Church and Wellesley Negihborhood(s) is 100:
# Number of Venuse in Coordination in St. James Town Negihborhood(s) is 100:
# Number of Venuse in Coordination in First Canadian Place, Underground city Negihborhood(s) is 100:
# Number of Venuse in Coordination in Chinatown, Grange Park, Kensington Market Negihborhood(s) is 100:
# Number of Venuse in Coordination in Cabbagetown, St. James Town Negihborhood(s) is 44:
# Number of Venuse in Coordination in Harbourfront, Regent Park Negihborhood(s) is 100:

# %%
downtown_venues.head()
# Out:
#   Postal Code Neighborhood  Neighborhood Latitude   ...            Venue Summary   Venue Category Distance
# 0         M5E  Berczy Park              43.644771   ...     This spot is popular       Steakhouse      244
# 1         M5E  Berczy Park              43.644771   ...     This spot is popular     Liquor Store      215
# 2         M5E  Berczy Park              43.644771   ...     This spot is popular           Museum      406
# 3         M5E  Berczy Park              43.644771   ...     This spot is popular   Farmers Market      465
# 4         M5E  Berczy Park              43.644771   ...     This spot is popular  Thai Restaurant      425
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Venues those are Neighborhood to Downtown Area

# %%
neigh_list = list(downtown_venues['Neighborhood'].unique())
neigh_list
# Out:
# ['Berczy Park',
#  'Rosedale',
#  'CN Tower, King and Spadina, Railway Lands, South Niagara',
#  'Commerce Court',
#  'Ryerson',
#  'Toronto Islands, Union Station',
#  'Design Exchange, Toronto Dominion Centre',
#  'University of Toronto',
#  'Adelaide, King',
#  'Church and Wellesley',
#  'St. James Town',
#  'First Canadian Place, Underground city',
#  'Chinatown, Grange Park, Kensington Market',
#  'Cabbagetown, St. James Town',
#  'Harbourfront, Regent Park']

# %% [markdown]
# ## Summerize the Key statistics about Venue Types

# %%
neigh_summ = downtown_venues.groupby('Neighborhood').count()
neigh_summ
# Out:
#                                                     Postal Code    ...     Distance
# Neighborhood                                                       ...
# Adelaide, King                                              100    ...          100
# Berczy Park                                                 100    ...          100
# CN Tower, King and Spadina, Railway Lands, Sout...           14    ...           14
# Cabbagetown, St. James Town                                  44    ...           44
# Chinatown, Grange Park, Kensington Market                   100    ...          100
# Church and Wellesley                                        100    ...          100
# Commerce Court                                              100    ...          100
# Design Exchange, Toronto Dominion Centre                    100    ...          100
# First Canadian Place, Underground city                      100    ...          100
# Harbourfront, Regent Park                                   100    ...          100
# Rosedale                                                     26    ...           26
# Ryerson                                                     100    ...          100
# St. James Town                                              100    ...          100
# Toronto Islands, Union Station                              100    ...          100
# University of Toronto                                       100    ...          100
#
# [15 rows x 7 columns]

# %%
neigh_category_stats = downtown_venues.groupby('Venue Category').count()
print("Total We have {} Unique Categories".format(len(downtown_venues['Venue Category'].unique())))
neigh_category_stats.head(10)
# Out:
# Total We have 195 Unique Categories
#                      Postal Code  Neighborhood  Neighborhood Latitude    ...     Venue  Venue Summary  Distance
# Venue Category                                                           ...
# Adult Boutique                 2             2                      2    ...         2              2         2
# Afghan Restaurant              1             1                      1    ...         1              1         1
# Airport                        1             1                      1    ...         1              1         1
# Airport Lounge                 1             1                      1    ...         1              1         1
# American Restaurant           23            23                     23    ...        23             23        23
# Animal Shelter                 1             1                      1    ...         1              1         1
# Aquarium                       3             3                      3    ...         3              3         3
# Art Gallery                   12            12                     12    ...        12             12        12
# Art Museum                     2             2                      2    ...         2              2         2
# Arts & Crafts Store            5             5                      5    ...         5              5         5
#
# [10 rows x 7 columns]

# %%
downtown_venues['Venue Category'].unique()
# Out:
# array(['Steakhouse', 'Liquor Store', 'Museum', 'Farmers Market',
#        'Thai Restaurant', 'Concert Hall', 'Cocktail Bar',
#        'Basketball Stadium', 'Food Truck', 'Beer Bar',
#        'Japanese Restaurant', 'Seafood Restaurant', 'Park',
#        'French Restaurant', 'Sporting Goods Shop', 'Tea Room',
#        'Coffee Shop', 'Bistro', 'Bakery', 'Jazz Club', 'Café', 'Lounge',
#        'Fish Market', 'Gastropub', 'Hotel', 'Restaurant', 'Cheese Shop',
#        'Gym', 'Cosmetics Shop', 'Creperie', 'Sports Bar',
#        'Belgian Restaurant', 'Beach', 'Comfort Food Restaurant',
#        'Fountain', 'Clothing Store', 'Church', 'Pub',
#        'Italian Restaurant', 'Diner', 'Grocery Store', 'Bagel Shop',
#        'Tailor Shop', 'Deli / Bodega', 'Salad Place', 'BBQ Joint',
#        'Art Gallery', 'Greek Restaurant', 'Lake', 'Office', 'Plaza',
#        'Pizza Place', 'Train Station', 'Supermarket', 'Breakfast Spot',
#        'Neighborhood', 'Optical Shop', 'Movie Theater',
#        'Middle Eastern Restaurant', 'American Restaurant',
#        'Bubble Tea Shop', 'Athletics & Sports', 'Filipino Restaurant',
#        'Pie Shop', 'Smoothie Shop', 'Bank', 'Sandwich Place',
#        'Playground', 'Trail', 'Hostel', 'Candy Store', 'Smoke Shop',
#        'Shopping Mall', 'Dog Run', 'Convenience Store', 'Metro Station',
#        'Airport', 'Harbor / Marina', 'Airport Lounge', 'Garden',
#        'Dance Studio', 'Scenic Lookout', 'Sculpture Garden', 'Track',
#        'Gym / Fitness Center', 'Ice Cream Shop',
#        'New American Restaurant', 'Gluten-free Restaurant',
#        'Monument / Landmark', 'Bar', 'Department Store', 'Speakeasy',
#        'General Travel', 'Food Court', 'Theater', 'Hotel Bar',
#        'Asian Restaurant', 'Fried Chicken Joint', 'Electronics Store',
#        'Noodle House', 'Bookstore', 'Mediterranean Restaurant',
#        'Burrito Place', 'Comic Shop', 'Taco Place', 'Ramen Restaurant',
#        'Vegetarian / Vegan Restaurant', 'Burger Joint', 'Music Venue',
#        'Spa', 'Mexican Restaurant', 'Falafel Restaurant',
#        'Miscellaneous Shop', 'Juice Bar', 'Sushi Restaurant',
#        'Furniture / Home Store', 'Historic Site', 'Yoga Studio',
#        'Fast Food Restaurant', 'Chinese Restaurant', 'Toy / Game Store',
#        'Dessert Shop', 'Art Museum', 'Brewery', 'Performing Arts Venue',
#        'Skating Rink', 'Aquarium', 'Event Space', 'Wine Bar',
#        'Baseball Stadium', 'History Museum', 'Indian Restaurant',
#        'Irish Pub', 'Brazilian Restaurant', 'College Gym', 'Music School',
#        'Gift Shop', 'Gaming Cafe', 'Dumpling Restaurant',
#        'Doner Restaurant', 'Korean Restaurant', 'Indie Movie Theater',
#        'Jewelry Store', 'Eastern European Restaurant',
#        'Ethiopian Restaurant', 'Persian Restaurant', 'Organic Grocery',
#        'Arts & Crafts Store', 'Record Shop', 'Hot Dog Joint',
#        'Caribbean Restaurant', 'Pastry Shop', 'Opera House',
#        'Salon / Barbershop', 'University', 'Souvlaki Shop', 'Piano Bar',
#        'Hobby Shop', 'Gay Bar', 'Adult Boutique', 'General Entertainment',
#        'Vietnamese Restaurant', "Men's Store", 'Wine Shop',
#        'Portuguese Restaurant', 'Sake Bar', 'Wings Joint',
#        'Video Game Store', 'Boutique', 'Afghan Restaurant', 'Nightclub',
#        'Health & Beauty Service', 'Poke Place',
#        'Latin American Restaurant', 'German Restaurant', 'Gourmet Shop',
#        'Snack Place', 'Martial Arts Dojo', 'Shoe Store', 'Street Art',
#        'Butcher', 'Pet Store', 'Farm', 'Taiwanese Restaurant',
#        'Rock Club', 'Library', 'Pool', 'Chocolate Shop', 'Tech Startup',
#        'Animal Shelter', 'Spanish Restaurant', 'Karaoke Bar',
#        'Beer Store', 'Auto Dealership', 'Discount Store'], dtype=object)

# %% [markdown]
# ### It is a promising situation that we have a huge business culture here contains more than 100 different types of business established here.

# %% [markdown]
# ## Thank You.
